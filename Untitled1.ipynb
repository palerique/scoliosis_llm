# %% [markdown]
# <a href="https://colab.research.google.com/github/palerique/scoliosis_llm/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: upload a file, save it to a variable and print the name of the received file

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  with open(fn, 'rb') as f:
    file_contents = f.read()
  # Process the file contents.
  # ...
  print(file_contents)
# Out:
#      <input type="file" id="files-8b4cbcf3-71ab-4088-a6d2-fec8338cb902" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b4cbcf3-71ab-4088-a6d2-fec8338cb902">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: above I have upload some files from my machine and saved them to the uploaded variable. Now I want to pre-process each of them, normalizing them and converting them to grayscale, them assigning them to a new variable so I can use the pre-processed images later

import numpy as np
import cv2

preprocessed_images = []

for fn in uploaded.keys():
  with open(fn, 'rb') as f:
    image_data = f.read()
  image = cv2.imdecode(np.frombuffer(image_data, dtype=np.uint8), cv2.IMREAD_COLOR)
  # Normalize the image
  image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
  # Convert the image to grayscale
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  preprocessed_images.append(image)

# Now you can use the preprocessed_images variable later in your code.

# %%
# prompt: show the pre-processed image

import matplotlib.pyplot as plt

plt.imshow(preprocessed_image, cmap='gray')
plt.axis('off')
plt.show()
